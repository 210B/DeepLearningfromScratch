# %% [markdown]
# # Ch2. 퍼셉트론

# %% [markdown]
# ## 2.2 단순 논리 회로

# %% [markdown]
# ### 2.2.1 AND 게이트

# %%
import numpy as np

# %%
def AND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

# %%
for x in [(0,0), (1,0), (0,1),(1,1)]:
    y = AND(x[0], x[1])
    print(str(x)+"->"+str(y))

# %% [markdown]
# ### 2.2.2 NAND 게이트

# %%
def NAND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])
    b = 0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

# %%
for x in [(0,0), (1,0), (0,1),(1,1)]:
    y = NAND(x[0], x[1])
    print(str(x)+"->"+str(y))
